# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('Melbourne_housing_extra_data.csv', sep=',')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19740 entries, 0 to 19739
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         19740 non-null  object
#  1   Address        19740 non-null  object
#  2   Rooms          19740 non-null  int64
#  3   Type           19740 non-null  object
#  4   Price          15396 non-null  float64
#  5   Method         19740 non-null  object
#  6   SellerG        19740 non-null  object
#  7   Date           19740 non-null  object
#  8   Distance       19732 non-null  float64
#  9   Postcode       19732 non-null  float64
#  10  Bedroom2       15327 non-null  float64
#  11  Bathroom       15327 non-null  float64
#  12  Car            15327 non-null  float64
#  13  Landsize       14944 non-null  float64
#  14  BuildingArea   8617 non-null   float64
#  15  YearBuilt      9351 non-null   float64
#  16  CouncilArea    15296 non-null  object
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  19740.000000  1.539600e+04  19732.000000  19732.000000  15327.000000
# mean       2.947163  1.054957e+06      9.861509   3106.533904      2.900568
# std        0.981048  6.452557e+05      5.554233     88.429928      1.007491
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.300000e+05      6.100000   3046.000000      2.000000
# 50%        3.000000  8.800000e+05      9.200000   3101.000000      3.000000
# 75%        4.000000  1.301000e+06     12.600000   3147.000000      3.000000
# max       12.000000  9.000000e+06     47.400000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  15327.000000  15327.000000   14944.000000   8617.000000  9351.000000
# mean       1.548509      1.578065     583.917090    196.806973  1874.165655
# ...

# %%
df.isnull().sum()
df.dropna(how='any',inplace=True)
df.info() #.info() function is used to get a concise summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6050 entries, 2 to 19739
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         6050 non-null   object
#  1   Address        6050 non-null   object
#  2   Rooms          6050 non-null   int64
#  3   Type           6050 non-null   object
#  4   Price          6050 non-null   float64
#  5   Method         6050 non-null   object
#  6   SellerG        6050 non-null   object
#  7   Date           6050 non-null   object
#  8   Distance       6050 non-null   float64
#  9   Postcode       6050 non-null   float64
#  10  Bedroom2       6050 non-null   float64
#  11  Bathroom       6050 non-null   float64
#  12  Car            6050 non-null   float64
#  13  Landsize       6050 non-null   float64
#  14  BuildingArea   6050 non-null   float64
#  15  YearBuilt      6050 non-null   float64
#  16  CouncilArea    6050 non-null   object
# ...

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (6050, 21)

# %%
df.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6050.000000  6.050000e+03  6050.000000  6050.000000  6050.000000
# mean      2.925455  1.071520e+06     9.659719  3101.719669     2.898843
# std       0.970501  6.744841e+05     5.500270    86.672469     0.970220
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.250000e+05     5.900000  3044.000000     2.000000
# 50%       3.000000  8.842500e+05     9.000000  3081.000000     3.000000
# 75%       4.000000  1.330000e+06    12.400000  3146.000000     3.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  6050.000000  6050.000000   6050.000000   6050.000000  6050.000000
# mean      1.574380     1.570744    556.156198    165.925240  1857.799271
# std       0.709502     0.936593    966.291345    268.494037   427.311004
# ...

# %%
plt.figure(figsize=(16,7))
sns.distplot(df['Rooms'])
# Out:
# C:\Python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rooms', ylabel='Density'>

# %%
plt.figure(figsize=(16,7))
sns.distplot(df['Price'])
# Out:
# C:\Python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
plt.figure(figsize=(16,7))
sns.distplot(df['YearBuilt'])
# Out:
# C:\Python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearBuilt', ylabel='Density'>

# %%
plt.figure(figsize=(16,7))
sns.distplot(df['BuildingArea'])
# Out:
# C:\Python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BuildingArea', ylabel='Density'>

# %%
plt.figure(figsize=(16,7))
sns.pairplot(df)

# %%
plt.figure(figsize=(16,7))
sns.countplot(data=df, x='Rooms', palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Rooms', ylabel='count'>

# %%
plt.figure(figsize=(40,12))
sns.countplot(data=df, x='Distance', palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Distance', ylabel='count'>

# %%
plt.figure(figsize=(16,7))
sns.boxplot(data=df, x='Rooms', y='Price', palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Rooms', ylabel='Price'>

# %%
plt.figure(figsize=(16,7))
sns.boxplot(data=df, x='Rooms', y='Distance', palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Rooms', ylabel='Distance'>

# %%
sns.jointplot(data=df, x='Rooms', y='Price')

# %%
sns.jointplot(data=df, x='Distance', y='Price')

# %%
corr =df.corr(method='kendall')

# %%
plt.figure(figsize=(16,7))
sns.heatmap(corr, annot=True)
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.insert(0, 'id', range(1, 1 + len(df)))

# %%
df.head()
# Out:
#     id      Suburb          Address  Rooms Type      Price Method SellerG  \
# 2    1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4    2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 6    3  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 11   4  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 14   5  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#          Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 2   4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 4   4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 6   4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
# 11  7/05/2016       2.5  ...       2.0  0.0     245.0         210.0
# 14  8/10/2016       2.5  ...       1.0  2.0     256.0         107.0
#
#     YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# ...

# %%
df.drop(['Address', 'SellerG','Lattitude','Longtitude', 'Date'], axis=1, inplace=True)
df.head()
# Out:
#     id      Suburb  Rooms Type      Price Method  Distance  Postcode  \
# 2    1  Abbotsford      2    h  1035000.0      S       2.5    3067.0
# 4    2  Abbotsford      3    h  1465000.0     SP       2.5    3067.0
# 6    3  Abbotsford      4    h  1600000.0     VB       2.5    3067.0
# 11   4  Abbotsford      3    h  1876000.0      S       2.5    3067.0
# 14   5  Abbotsford      2    h  1636000.0      S       2.5    3067.0
#
#     Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt CouncilArea  \
# 2        2.0       1.0  0.0     156.0          79.0     1900.0       Yarra
# 4        3.0       2.0  0.0     134.0         150.0     1900.0       Yarra
# 6        3.0       1.0  2.0     120.0         142.0     2014.0       Yarra
# 11       4.0       2.0  0.0     245.0         210.0     1910.0       Yarra
# 14       2.0       1.0  2.0     256.0         107.0     1890.0       Yarra
#
#                Regionname  Propertycount
# 2   Northern Metropolitan         4019.0
# ...

# %%
#Encoding Data

# %%
def Encode(df):
    for column in df.columns[df.columns.isin(['Suburb','Method','CouncilArea','Regionname', 'Type'])]:
        df[column] = df[column].factorize()[0]
    return df

df_en = Encode(df.copy())

# %%
df_en.head(20)
# Out:
#     id  Suburb  Rooms  Type      Price  Method  Distance  Postcode  Bedroom2  \
# 2    1       0      2     0  1035000.0       0       2.5    3067.0       2.0
# 4    2       0      3     0  1465000.0       1       2.5    3067.0       3.0
# 6    3       0      4     0  1600000.0       2       2.5    3067.0       3.0
# 11   4       0      3     0  1876000.0       0       2.5    3067.0       4.0
# 14   5       0      2     0  1636000.0       0       2.5    3067.0       2.0
# 18   6       0      2     0  1097000.0       0       2.5    3067.0       3.0
# 24   7       0      3     0  1350000.0       2       2.5    3067.0       3.0
# 25   8       0      2     1   750000.0       0       2.5    3067.0       2.0
# 30   9       0      2     0  1310000.0       0       2.5    3067.0       2.0
# 32  10       0      3     0  1200000.0       0       2.5    3067.0       3.0
# 35  11       0      3     0  1176500.0       0       2.5    3067.0       2.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df_en[['id', 'Suburb', 'Rooms', 'Type', 'Method', 'Distance','Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea',
'YearBuilt', 'CouncilArea', 'Regionname', 'Propertycount']]

# %%
y=df_en['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm_model = LinearRegression()

# %%
lm_model
# Out:
# LinearRegression()

# %%
lm_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm_model.intercept_
# Out:
# -3804785.438911613

# %%
lm_model.coef_
# Out:
# array([ 4.25015380e+00, -9.86732473e+02,  3.09005120e+05, -2.21845213e+05,
#        -3.42822820e+04, -5.40530318e+04,  1.35693586e+03, -4.73286302e+04,
#         2.19913934e+05,  5.56695760e+04,  1.32464355e+01,  5.06130611e+01,
#         8.53321133e+00, -4.95214273e+03,  1.19753865e+05,  3.35746232e+00])

# %%
coefficients =pd.DataFrame(lm_model.coef_, X.columns, columns=['columns'])

# %%
coefficients
# Out:
#                      columns
# id                  4.250154
# Suburb           -986.732473
# Rooms          309005.119695
# Type          -221845.213397
# Method         -34282.282038
# Distance       -54053.031819
# Postcode         1356.935860
# Bedroom2       -47328.630155
# Bathroom       219913.934275
# Car             55669.575966
# Landsize           13.246436
# BuildingArea       50.613061
# YearBuilt           8.533211
# CouncilArea     -4952.142731
# Regionname     119753.865119
# Propertycount       3.357462

# %%
#Predictions

# %%
predictions = lm_model.predict(X_test)

# %%
predictions
# Out:
# array([1293934.45757184,  910264.19046361, 1287045.69850058, ...,
#         425349.9466881 , 1422962.48854673, 1062421.83730091])

# %%
newpredictions = np.round(predictions, 2)

# %%
newpredictions
# Out:
# array([1293934.46,  910264.19, 1287045.7 , ...,  425349.95, 1422962.49,
#        1062421.84])

# %%
finalpredictions = pd.DataFrame({'Id': X_test.id, 'Real_price': y_test, 'Predicted_price': newpredictions})

# %%
finalpredictions
# Out:
#          Id  Real_price  Predicted_price
# 5023   1696   1680000.0       1293934.46
# 9540   3165    390000.0        910264.19
# 12025  3976   1260000.0       1287045.70
# 12600  4122    701000.0        972879.43
# 8395   2779    380000.0        346933.18
# ...     ...         ...              ...
# 883     299    500000.0        919079.83
# 183      69   2140000.0       2221449.10
# 19719  6041    678000.0        425349.95
# 2292    737   1790000.0       1422962.49
# 4758   1599    550000.0       1062421.84
#
# [1815 rows x 3 columns]

# %%
finalpredictions.to_csv('Final_predictions_LinearRegression_HousingPrices.csv', index=False)

# %%
X_test['Predicted_Price'] = newpredictions

# %%
X_test
# Out:
#          id  Suburb  Rooms  Type  Method  Distance  Postcode  Bedroom2  \
# 5023   1696      51      4     0       0      13.7    3188.0       4.0
# 9540   3165      91      2     1       2       6.1    3182.0       2.0
# 12025  3976     132      4     0       0      12.5    3041.0       4.0
# 12600  4122      31      3     1       3      13.6    3148.0       3.0
# 8395   2779      83      2     1       0      11.2    3073.0       2.0
# ...     ...     ...    ...   ...     ...       ...       ...       ...
# 883     299      12      2     0       0       9.7    3103.0       2.0
# 183      69       2      4     0       0       3.3    3206.0       3.0
# 19719  6041     184      2     0       0      14.7    3030.0       3.0
# 2292    737      20      4     0       0       5.2    3056.0       3.0
# 4758   1599      48      4     0       2      13.0    3046.0       4.0
#
#        Bathroom  Car  Landsize  BuildingArea  YearBuilt  CouncilArea  \
# ...

# %%
X_test['Real_price'] = y_test

# %%
X_test
# Out:
#          id  Suburb  Rooms  Type  Method  Distance  Postcode  Bedroom2  \
# 5023   1696      51      4     0       0      13.7    3188.0       4.0
# 9540   3165      91      2     1       2       6.1    3182.0       2.0
# 12025  3976     132      4     0       0      12.5    3041.0       4.0
# 12600  4122      31      3     1       3      13.6    3148.0       3.0
# 8395   2779      83      2     1       0      11.2    3073.0       2.0
# ...     ...     ...    ...   ...     ...       ...       ...       ...
# 883     299      12      2     0       0       9.7    3103.0       2.0
# 183      69       2      4     0       0       3.3    3206.0       3.0
# 19719  6041     184      2     0       0      14.7    3030.0       3.0
# 2292    737      20      4     0       0       5.2    3056.0       3.0
# 4758   1599      48      4     0       2      13.0    3046.0       4.0
#
#        Bathroom  Car  Landsize  BuildingArea  YearBuilt  CouncilArea  \
# ...

# %%
X_test.to_csv('CompleteFinalPredictions-Housing.csv', index=False)

# %%
#Evaluation

# %%
from sklearn import metrics

# %%
print ('MAE:',  metrics.mean_absolute_error(y_test, newpredictions))
# Out:
# MAE: 302441.85441873275

# %%
print ('MSE:',  metrics.mean_squared_error(y_test, newpredictions))
# Out:
# MSE: 181309481310.3089

# %%
print ('RMSE:',  np.sqrt(metrics.mean_absolute_error(y_test, newpredictions)))
# Out:
# RMSE: 549.9471378402953

# %%
r2_score=lm_model.score(X,y)
print('R^2 score:',r2_score)
# Out:
# R^2 score: 0.5475844511841736

# %%
plt.scatter(y_test, predictions)
plt.ylim([200000,1000000])
plt.xlim([200000,1000000])
# Out:
# (200000.0, 1000000.0)

# %%
sns.distplot((y_test-predictions),bins=50)
# Out:
# C:\Python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>
